# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\gupta\OneDrive\Attachments\Downloads\house_price_regression_dataset (1).csv")
df
# Out:
#       Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0               4143             5              2        2003  3.293187
# 1               3168             3              3        2015  1.401652
# 2               3369             2              3        1962  3.584279
# 3               4087             3              2        2001  3.729464
# 4               2932             2              2        1985  2.686542
# ...              ...           ...            ...         ...       ...
# 5995            4406             4              1        1989  3.399706
# 5996            4940             1              1        1952  1.746339
# 5997            3762             4              3        1958  1.449916
# 5998            2381             3              1        2022  2.486320
# 5999            1484             5              1        2010  1.246555
#
#       Garage_Size  Neighborhood_Quality    House_Price
# ...

# %%
#Data Information Gathering
df.shape
# Out:
# (6000, 8)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Square_Footage        6000 non-null   int64
#  1   Num_Bedrooms          6000 non-null   int64
#  2   Num_Bathrooms         6000 non-null   int64
#  3   Year_Built            6000 non-null   int64
#  4   Lot_Size              6000 non-null   float64
#  5   Garage_Size           6000 non-null   int64
#  6   Neighborhood_Quality  6000 non-null   int64
#  7   House_Price           6000 non-null   float64
# dtypes: float64(2), int64(6)
# memory usage: 375.1 KB

# %%
df.min()
# Out:
# Square_Footage             501.000000
# Num_Bedrooms                 1.000000
# Num_Bathrooms                1.000000
# Year_Built                1950.000000
# Lot_Size                     0.500042
# Garage_Size                  0.000000
# Neighborhood_Quality         1.000000
# House_Price             100000.000000
# dtype: float64

# %%
df.max()
# Out:
# Square_Footage          4.999000e+03
# Num_Bedrooms            5.000000e+00
# Num_Bathrooms           3.000000e+00
# Year_Built              2.022000e+03
# Lot_Size                4.998627e+00
# Garage_Size             2.000000e+00
# Neighborhood_Quality    1.000000e+01
# House_Price             1.127455e+06
# dtype: float64

# %%
df.head()
# Out:
#    Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 0            4143             5              2        2003  3.293187
# 1            3168             3              3        2015  1.401652
# 2            3369             2              3        1962  3.584279
# 3            4087             3              2        2001  3.729464
# 4            2932             2              2        1985  2.686542
#
#    Garage_Size  Neighborhood_Quality    House_Price
# 0            2                     6  921504.973171
# 1            0                     1  676616.093190
# 2            1                     9  728289.887312
# 3            1                     6  903580.584732
# 4            0                     4  619113.800643

# %%
df.tail()
# Out:
#       Square_Footage  Num_Bedrooms  Num_Bathrooms  Year_Built  Lot_Size  \
# 5995            4406             4              1        1989  3.399706
# 5996            4940             1              1        1952  1.746339
# 5997            3762             4              3        1958  1.449916
# 5998            2381             3              1        2022  2.486320
# 5999            1484             5              1        2010  1.246555
#
#       Garage_Size  Neighborhood_Quality    House_Price
# 5995            2                     7  956238.304660
# 5996            2                     5  970202.792427
# 5997            0                     7  761935.641864
# 5998            2                    10  568549.611410
# 5999            1                     6  360372.978039

# %%
df.mean()
# Out:
# Square_Footage            2783.891000
# Num_Bedrooms                 2.972167
# Num_Bathrooms                1.995000
# Year_Built                1986.068500
# Lot_Size                     2.736645
# Garage_Size                  0.987833
# Neighborhood_Quality         5.614167
# House_Price             611302.429841
# dtype: float64

# %%
df.median()
# Out:
# Square_Footage            2824.000000
# Num_Bedrooms                 3.000000
# Num_Bathrooms                2.000000
# Year_Built                1986.000000
# Lot_Size                     2.737869
# Garage_Size                  1.000000
# Neighborhood_Quality         6.000000
# House_Price             614613.995308
# dtype: float64

# %%
df.std()
# Out:
# Square_Footage            1280.160843
# Num_Bedrooms                 1.425037
# Num_Bathrooms                0.814710
# Year_Built                  21.189234
# Lot_Size                     1.299583
# Garage_Size                  0.825307
# Neighborhood_Quality         2.860710
# House_Price             257881.504426
# dtype: float64

# %%
df.count()
# Out:
# Square_Footage          6000
# Num_Bedrooms            6000
# Num_Bathrooms           6000
# Year_Built              6000
# Lot_Size                6000
# Garage_Size             6000
# Neighborhood_Quality    6000
# House_Price             6000
# dtype: int64

# %%
df.describe()
# Out:
#        Square_Footage  Num_Bedrooms  Num_Bathrooms   Year_Built     Lot_Size  \
# count     6000.000000   6000.000000     6000.00000  6000.000000  6000.000000
# mean      2783.891000      2.972167        1.99500  1986.068500     2.736645
# std       1280.160843      1.425037        0.81471    21.189234     1.299583
# min        501.000000      1.000000        1.00000  1950.000000     0.500042
# 25%       1667.000000      2.000000        1.00000  1967.000000     1.608054
# 50%       2824.000000      3.000000        2.00000  1986.000000     2.737869
# 75%       3876.250000      4.000000        3.00000  2005.000000     3.865461
# max       4999.000000      5.000000        3.00000  2022.000000     4.998627
#
#        Garage_Size  Neighborhood_Quality   House_Price
# count  6000.000000           6000.000000  6.000000e+03
# mean      0.987833              5.614167  6.113024e+05
# std       0.825307              2.860710  2.578815e+05
# ...

# %%
df.isnull().sum()
# Out:
# Square_Footage          0
# Num_Bedrooms            0
# Num_Bathrooms           0
# Year_Built              0
# Lot_Size                0
# Garage_Size             0
# Neighborhood_Quality    0
# House_Price             0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
columns = ['Year_Built', 'Square_Footage','Num_Bedrooms','Num_Bathrooms','Lot_Size','Garage_Size','Neighborhood_Quality']

for col in columns:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower) | (df[col] > upper)]

    print(f"{col}")
    print(f"Outliers: {len(outliers)}")
    print(f"Percentage: {(len(outliers)/len(df))*100:.2f}%\n")
# Out:
# Year_Built
# Outliers: 0
# Percentage: 0.00%
#
# Square_Footage
# Outliers: 0
# Percentage: 0.00%
#
# Num_Bedrooms
# Outliers: 0
# Percentage: 0.00%
#
# Num_Bathrooms
# Outliers: 0
# Percentage: 0.00%
#
# Lot_Size
# Outliers: 0
# Percentage: 0.00%
#
# Garage_Size
# Outliers: 0
# Percentage: 0.00%
#
# Neighborhood_Quality
# Outliers: 0
# Percentage: 0.00%

# %%
sns.scatterplot(x="Square_Footage",y="House_Price",data=df)
# Out:
# <Axes: xlabel='Square_Footage', ylabel='House_Price'>

# %%
sns.boxplot(x ='Year_Built',data=df)
# Out:
# <Axes: xlabel='Year_Built'>

# %%
sns.boxplot(x ='Square_Footage',data=df)
# Out:
# <Axes: xlabel='Square_Footage'>

# %%
sns.boxplot(x ='Num_Bedrooms',data=df)
# Out:
# <Axes: xlabel='Num_Bedrooms'>

# %%
sns.boxplot(x ='Num_Bathrooms',data=df)
# Out:
# <Axes: xlabel='Num_Bathrooms'>

# %%
sns.boxplot(x ='Lot_Size',data=df)
# Out:
# <Axes: xlabel='Lot_Size'>

# %%
sns.regplot(x='Year_Built',y='House_Price',data=df)
# Out:
# <Axes: xlabel='Year_Built', ylabel='House_Price'>

# %%
sns.boxplot(x ='Garage_Size',data=df)
# Out:
# <Axes: xlabel='Garage_Size'>

# %%
sns.boxplot(x ='Neighborhood_Quality',data=df)
# Out:
# <Axes: xlabel='Neighborhood_Quality'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
from sklearn.model_selection import train_test_split
x= df[['Square_Footage','Year_Built','Num_Bedrooms','Num_Bathrooms','Lot_Size','Garage_Size','Neighborhood_Quality']]
y=df['House_Price']
x_train,x_test,y_train,y_test= train_test_split(x,y,test_size=0.20, random_state=42)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=45)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
regression_lr=LinearRegression()
regression_lr.fit(x_train,y_train)
y_pred=regression_lr.predict(x_test)
s_lr=r2_score(y_test,y_pred)
print(s_lr)
# Out:
# 0.9985110794581993

# %%
p_lr=regression_lr.predict([[1360,1981,5,2,3.29318701850776,2,6]])
p_lr1=regression_lr.predict([[4272,2016,3,3,1.40165192634416,0,1]])
p_lr2=regression_lr.predict([[3592,2016,2,3,3.58427904550702,1,9]])
# Out:
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
regression_dt=DecisionTreeRegressor(max_depth=5,
    min_samples_split=5,
    min_samples_leaf=2)
regression_dt.fit(x_train,y_train)
y_pred=regression_dt.predict(x_test)
s_dt=r2_score(y_test,y_pred)
print(s_dt)
# Out:
# 0.9818983030570115

# %%
p_dt=regression_dt.predict([[1360,1981,5,2,3.29318701850776,2,6]])
p_dt1=regression_dt.predict([[4272,2016,3,3,1.40165192634416,0,1]])
p_dt2=regression_dt.predict([[3592,2016,2,3,3.58427904550702,1,9]])
# Out:
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
regression_rf=RandomForestRegressor( n_estimators=100,      
    max_depth=10,          
    min_samples_split=5,  
    min_samples_leaf=2)
regression_rf.fit(x_train,y_train)
y_pred=regression_rf.predict(x_test)
s_rf=r2_score(y_test,y_pred)
print(s_rf)
# Out:
# 0.995973993347788

# %%
p_rf=regression_dt.predict([[1360,1981,5,2,3.29318701850776,2,6]])
p_rf1=regression_dt.predict([[4272,2016,3,3,1.40165192634416,0,1]])
p_rf2=regression_dt.predict([[3592,2016,2,3,3.58427904550702,1,9]])
# Out:
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
from sklearn.svm import SVR
from sklearn.metrics import r2_score
regression_svr=SVR(kernel='rbf',
    C=100,
    gamma='scale',
    epsilon=0.1)
regression_svr.fit(x_train,y_train)
y_pred=regression_svr.predict(x_test)
s_svr=r2_score(y_test,y_pred)
print(s_svr)
# Out:
# 0.4994263068563546

# %%
p_svr=regression_dt.predict([[1360,1981,5,2,3.29318701850776,2,6]])
p_svr1=regression_dt.predict([[4272,2016,3,3,1.40165192634416,0,1]])
p_svr2=regression_dt.predict([[3592,2016,2,3,3.58427904550702,1,9]])
# Out:
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import r2_score
regression_knn=KNeighborsRegressor(n_neighbors=5,
    weights='uniform',
    metric='minkowski',
    p=2)
regression_knn.fit(x_train,y_train)
y_pred=regression_knn.predict(x_test)
s_knn=r2_score(y_test,y_pred)
print(s_knn)
# Out:
# 0.9865394860243419

# %%
p_knn=regression_dt.predict([[1360,1981,5,2,3.29318701850776,2,6]])
p_knn1=regression_dt.predict([[4272,2016,3,3,1.40165192634416,0,1]])
p_knn2=regression_dt.predict([[3592,2016,2,3,3.58427904550702,1,9]])
# Out:
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import r2_score
regression_gbr=GradientBoostingRegressor( n_estimators=100,
    learning_rate=0.1,
    max_depth=3,
    random_state=42)
regression_gbr.fit(x_train,y_train)
y_pred=regression_gbr.predict(x_test)
s_gbr=r2_score(y_test,y_pred)
print(s_gbr)
# Out:
# 0.9975960502610017

# %%
p_gbr=regression_dt.predict([[1360,1981,5,2,3.29318701850776,2,6]])
p_gbr1=regression_dt.predict([[4272,2016,3,3,1.40165192634416,0,1]])
p_gbr2=regression_dt.predict([[3592,2016,2,3,3.58427904550702,1,9]])
# Out:
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
# C:\Users\gupta\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(

# %%
###### import pandas as pd
a = pd.DataFrame({'Algorithm': ['Linear Regression', 'Decision Tree Regressor', 'Random Forest Regressor', 
                                'Support Vector Machine Regressor ', 'K-Nearest Neighbhor Regressor', 
                                'Gradient Boosting Regressor'],
                 'R2Score': [s_lr,s_dt,s_rf, s_svr,s_knn,s_gbr],
                 'Actual1':[262382.852274056,262382.852274056,262382.852274056,262382.852274056,262382.852274056,262382.852274056],
                 'Prediction1':[p_lr,p_dt,p_rf,p_svr, p_knn,p_gbr],
                 'Actual2':[985260.854490162,985260.854490162,985260.854490162,985260.854490162,985260.854490162,985260.854490162],
                 'Prediction2':[p_lr1,p_dt1,p_rf1,p_svr1, p_knn1,p_gbr1],  # Added missing colon
                 'Actual3':[777977.390118581,777977.390118581,777977.390118581,777977.390118581,777977.390118581,777977.390118581],
                 'Prediction3':[p_lr2,p_dt2,p_rf2,p_svr2, p_knn2,p_gbr2]})  # Added missing colon and changed key name
a
# Out:
#                            Algorithm   R2Score        Actual1  \
# 0                  Linear Regression  0.998511  262382.852274
# 1            Decision Tree Regressor  0.981898  262382.852274
# 2            Random Forest Regressor  0.995974  262382.852274
# 3  Support Vector Machine Regressor   0.499426  262382.852274
# 4      K-Nearest Neighbhor Regressor  0.986539  262382.852274
# 5        Gradient Boosting Regressor  0.997596  262382.852274
#
#            Prediction1       Actual2          Prediction2        Actual3  \
# 0  [355407.4754442412]  985260.85449  [921293.9222530501]  777977.390119
# 1  [367603.7596475111]  985260.85449  [927159.6681014025]  777977.390119
# 2  [367603.7596475111]  985260.85449  [927159.6681014025]  777977.390119
# 3  [367603.7596475111]  985260.85449  [927159.6681014025]  777977.390119
# 4  [367603.7596475111]  985260.85449  [927159.6681014025]  777977.390119
# 5  [367603.7596475111]  985260.85449  [927159.6681014025]  777977.390119
#
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.metrics import r2_score
regression_dt=DecisionTreeRegressor(max_depth=5,
    min_samples_split=5,
    min_samples_leaf=2)
regression_dt.fit(x_train,y_train)
y_pred=regression_dt.predict(x_test)
s_dt=r2_score(y_test,y_pred)
print(s_dt)
# Out:
# 0.9824328158875719

# %%
import matplotlib.pyplot as plt
from sklearn.tree import plot_tree
f_col = ["Square_Footage", "Year_Built","Num_Bedrooms","Num_Bathrooms","Lot_Size","Garage_Size","Neighborhood_Quality"]

plt.figure(figsize=(15,8))

plot_tree(
    regression_dt,
    filled=True,
    feature_names=f_col,
    class_names=True
)

plt.show()

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score
regression_rf=RandomForestRegressor( n_estimators=100,      
    max_depth=10,          
    min_samples_split=5,  
    min_samples_leaf=2)
regression_rf.fit(x_train,y_train)
y_pred=regression_rf.predict(x_test)
s_rf=r2_score(y_test,y_pred)
print(s_rf)
# Out:
# 0.9959630361044439

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

f_col = ["Square_Footage", "Year_Built","Num_Bedrooms","Num_Bathrooms","Lot_Size","Garage_Size","Neighborhood_Quality"]
plt.figure(figsize=(15, 10))

plot_tree(
    regression_rf.estimators_[0],   
    feature_names=f_col,
    filled=True,
    rounded=True,
    max_depth=5          
)

plt.show()
